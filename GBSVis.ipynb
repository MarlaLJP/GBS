# %% [markdown]
# <a href="https://colab.research.google.com/github/MarlaLJP/GBS/blob/main/GBSVis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)
library(vegan)
# Out:
# Loading required package: permute

# %%
data = read.delim("GBS.gz")
